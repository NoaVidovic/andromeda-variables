# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_epoch = pd.read_csv('epoch_photometry_data.csv')
data_source = pd.read_csv('jobresult03_parallax_filter.csv')

# %%
source_ids = data_epoch['source_id'].unique()

def where(cond, df=data_epoch):
    return df.loc[cond]

def where_eq(column, eq, df=data_epoch):
    return where(df[column] == eq, df=df)

def where_source_num(index):
    return where(data_epoch.source_id == source_ids[index])

# %%
G, BP, RP = 'G', 'BP', 'RP'

def chi_square(source_id, band):
    if band not in (G, BP, RP):
        return
        
    time_data = where_eq('band', band, df=where_eq('source_id', source_id, df=data_epoch))
    mean_mag = where_eq('source_id', source_id, df=data_source)[f'phot_{band.lower()}_mean_mag']
    
    n = len(time_data)
    ret = 0
    c = 2.5 / np.log(10)
    
    for mag, flux, flux_error in zip(time_data['mag'], time_data['flux'], time_data['flux_error']):
        mag_error = c * flux_error/flux
        ret += (mag - mean_mag)**2 / mag_error**2
        
    return ret / (n-1)

# %%
k = [ float(chi_square(sid, G)) for sid in source_ids ]
k_rp = [ float(chi_square(sid, RP)) for sid in source_ids ]
k_bp = [ float(chi_square(sid, BP)) for sid in source_ids ]

# %%
chi_square_data = pd.DataFrame(zip(source_ids, k, k_rp, k_bp),
                               columns=['source_id', 'chi_square_g', 'chi_square_rp', 'chi_square_bp']
                              )
chi_square_data.to_csv('chi_square_data.csv')

# %%
def draw_light_curves(n, ind=True):
    if ind:
        s = where_source_num(n)
    else:
        s = where_eq('source_id', n)
        
    s_g = where_eq('band', 'G', s)
    s_bp = where_eq('band', 'BP', s)
    s_rp = where_eq('band', 'RP', s)
    
    fig, ax = plt.subplots(3)
    
    ax[0].plot(s_g.time, s_g.mag)
    ax[0].invert_yaxis()
    ax[0].set_yscale('log')
    
    ax[1].plot(s_bp.time, s_bp.mag)
    ax[1].invert_yaxis()
    ax[1].set_yscale('log')
    
    ax[2].plot(s_rp.time, s_rp.mag)
    ax[2].invert_yaxis()
    ax[2].set_yscale('log')

# %%
draw_light_curves(385623054556280832, ind=False)

# %%
variables = where_eq('phot_variable_flag', 'VARIABLE', df=data_source)
variables
# Out:
#                 source_id         ra        dec  parallax  parallax_error  \
# 1      385497744590070912   3.992995  43.658760  1.101956        1.387515
# 21     385524824361687040   4.361768  44.097955 -1.445585        0.807520
# 38     385623054556280832   5.814056  43.540757  0.353208        0.535477
# 105    385642467808657408   5.347761  43.848856 -0.074159        0.281066
# 114    383377817452439168   4.391577  40.469027 -0.075099        0.232419
# ...                   ...        ...        ...       ...             ...
# 64460  376172855195389056  16.290599  43.122059  0.452777        1.124210
# 64465  376174405678861824  16.154917  42.892601  0.280405        0.311497
# 64470  376174710621088256  16.114344  42.936737 -0.424757        0.538106
# 64480  376177665558693632  16.097632  43.044860  0.095559        0.742431
# 64498  376181754367604096  15.889833  43.104589 -0.482348        0.659821
#
#            pmra  pmra_error     pmdec  pmdec_error  astrometric_params_solved  \
# 1     -0.792380    1.609943  1.704215     1.571880                         31
# 21    -0.648387    0.667193 -0.451219     0.505398                         95
# 38    -0.023378    0.461431  0.026728     0.296253                         31
# 105    0.133175    0.256687 -0.053446     0.178845                         31
# 114   -0.204254    0.169675 -0.122556     0.119110                         31
# ...         ...         ...       ...          ...                        ...
# 64460 -0.316480    1.082918 -0.680965     0.705184                         31
# 64465 -0.189487    0.232905 -0.165021     0.187309                         31
# 64470 -0.043898    0.453034  0.667781     0.352953                         31
# 64480 -0.090890    0.872430 -0.119267     0.402555                         95
# 64498  0.235842    0.618629 -0.639145     0.399269                         31
#
#        ...  pseudocolour_error  phot_g_mean_mag  phot_bp_mean_mag  \
# 1      ...                 NaN        20.755340         20.900755
# 21     ...            0.160023        20.310585         20.029263
# 38     ...                 NaN        20.180584         20.426676
# 105    ...                 NaN        19.488178         19.699684
# 114    ...                 NaN        19.014465         19.175568
# ...    ...                 ...              ...               ...
# 64460  ...                 NaN        20.595167         21.013279
# 64465  ...                 NaN        19.334028         19.486862
# 64470  ...                 NaN        20.123993         20.246447
# 64480  ...            0.125395        20.248884         19.800959
# 64498  ...                 NaN        20.383781         20.727000
#
#        phot_rp_mean_mag     bp_rp  radial_velocity  radial_velocity_error  \
# 1             20.689070  0.211685              NaN                    NaN
# 21            18.610626  1.418636              NaN                    NaN
# 38            19.858768  0.567907              NaN                    NaN
# 105           19.192700  0.506985              NaN                    NaN
# 114           18.708527  0.467041              NaN                    NaN
# ...                 ...       ...              ...                    ...
# 64460         20.218985  0.794294              NaN                    NaN
# 64465         18.929660  0.557201              NaN                    NaN
# 64470         19.518406  0.728041              NaN                    NaN
# 64480         18.537216  1.263742              NaN                    NaN
# 64498         19.830467  0.896532              NaN                    NaN
#
#        phot_variable_flag    ecl_lat  nu_eff_used_in_astrometry
# 1                VARIABLE  37.832515                   1.576564
# 21               VARIABLE  38.078327                        NaN
# 38               VARIABLE  37.071919                   1.601674
# 105              VARIABLE  37.506931                   1.602413
# 114              VARIABLE  34.911324                   1.613760
# ...                   ...        ...                        ...
# 64460            VARIABLE  33.072994                   1.656227
# 64465            VARIABLE  32.913889                   1.617424
# 64470            VARIABLE  32.966714                   1.527595
# 64480            VARIABLE  33.068526                        NaN
# 64498            VARIABLE  33.190973                   1.543085
#
# [3121 rows x 21 columns]

# %%
chi_square_data
# Out:
#                 source_id  chi_square_g  chi_square_rp  chi_square_bp
# 0      383805836714177920     11.344171       3.597695       5.299525
# 1      385497744590070912      9.003312       2.309269       2.287948
# 2      385498225626420352      1.958113       6.581904       3.280803
# 3      385498294346907520      2.761481       4.725604       3.938151
# 4      385515989612893696      7.611866       9.596345       4.670326
# ...                   ...           ...            ...            ...
# 64496  376181277625179904      1.714699       8.357478       4.033018
# 64497  376181307691031808      1.556267       9.715839       8.415178
# 64498  376181754367604096      7.054770      12.022176       4.595985
# 64499  376181994885798528      1.082537       6.416493       1.518102
# 64500  376182097965021952      1.318935       6.842179       4.910718
#
# [64501 rows x 4 columns]

# %%
where_eq('source_id', 376172855195389056, df=chi_square_data)
# Out:
#                 source_id  chi_square_g  chi_square_rp  chi_square_bp
# 64460  376172855195389056     11.666372      10.970206      13.740214
