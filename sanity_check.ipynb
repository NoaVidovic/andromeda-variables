# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from astroquery.gaia import Gaia

# %%
data_unfiltered = pd.read_csv('jobresult00_unfiltered.csv')
data_filtered = pd.read_csv('jobresult03_parallax_filter.csv')

# %%
data_filtered
# Out:
#                 source_id         ra        dec  parallax  parallax_error  \
# 0      383805836714177920   3.939743  42.223791 -0.148159        0.548134
# 1      385497744590070912   3.992995  43.658760  1.101956        1.387515
# 2      385498225626420352   3.991615  43.687892 -1.345057        0.794944
# 3      385498294346907520   3.998289  43.710889  0.803850        0.533063
# 4      385515989612893696   4.337738  43.896320  0.390385        0.521188
# ...                   ...        ...        ...       ...             ...
# 64496  376181277625179904  15.991880  43.128023 -0.928156        1.023764
# 64497  376181307691031808  16.010012  43.133627  2.357444        1.453334
# 64498  376181754367604096  15.889833  43.104589 -0.482348        0.659821
# 64499  376181994885798528  15.959665  43.133741  0.650074        0.661809
# 64500  376182097965021952  15.957400  43.143336  0.040050        0.573453
#
#            pmra  pmra_error     pmdec  pmdec_error  astrometric_params_solved  \
# ...

# %%
plt.hexbin(data_filtered['ra'], data_filtered['dec'])

# %%
plt.hexbin(data_unfiltered['ra'], data_unfiltered['dec'])
